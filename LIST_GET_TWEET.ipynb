# %%
import numpy as np
import sys,os
import config2
import pandas as pd
CONSUMER_KEY    = config2.CONSUMER_KEY
CONSUMER_SECRET = config2.CONSUMER_SECRET
ACCESS_TOKEN = config2.ACCESS_TOKEN
ACCESS_TOKEN_SECRET = config2.ACCESS_TOKEN_SECRET
import tweepy
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth,wait_on_rate_limit = True)#,wait_on_rate_limit_notify= True #PLOT TIME
df2=pd.Series()

# %%
cnt=200
#user=['doredora007','toshio_tamogami','yukehaya']
def get_tweet_and_count(user_id,cnt):
    A=[]
    j=0
    try :
        a=api.user_timeline(user_id,count=cnt)
    except:
        pass
    else:
        for i in range(cnt):
            try:
                A.append(a[i].text)
            except:
                pass
            else:
                #print(A[i])
                j+=1
        print('=========',j)
        user_choice=a[0].user.id_str
        df0=pd.Series([user_choice]*cnt)
        df1=pd.Series(A)
        df2=pd.concat([df0,df1],axis=1)
    return df2

# %%
df=pd.read_csv('party.csv',dtype='uint64')
df=df.drop("58184",axis=1)
#任意列を削除
#多すぎるので１０００人までリクエストする。
df=df[0:1000]
df=df.to_numpy(int)
A=[]
for i in df:
    a=int(i)
    A.append(a)

# %%
#A=A[100:70]
len(A)
# Out:
# 1000

# %%
def list_get(list):
    dfgh=pd.DataFrame()
    print(A)
    for i in range(600):
        try:
            df=get_tweet_and_count(A[i],cnt)
        except:
            pass
        else:
            dfgh=dfgh.append(df)
    return dfgh

# %%
tweet_list=list_get(A)
# Out:
# [107914857, 2877651816, 2276883054, 928319429259149184, 1093399618908413952, 1120121826397442048, 171273202, 2946803768, 933882270527524864, 4639936932, 3311334187, 902903282946908160, 174902301, 1183178208398602240, 1107266121483194368, 804034292, 1107260433558233216, 924953676459810816, 702743163916582912, 970981530427211776, 1519175312, 25624275, 252997912, 3305708852, 307377608, 1121111680883105792, 749918002267598848, 303830133, 1119203523135033216, 614033323, 3251082536, 2239199006, 1179044412128522240, 891642088638488576, 116374982, 304860905, 709641773987930112, 2406731161, 1134715328099840000, 1138538364464816000, 4689769650, 1141977372096266240, 1019933145049600000, 880670687127629824, 828376689063272448, 15285337, 420898754, 381794687, 121958103, 132545869, 1028658786783780864, 1187943774057447424, 313652343, 1031949045172850816, 1120484055563112448, 124750923, 126525734, 1401335041, 1036555478384275584, 1150331433698779136, 1146982854489825152, 365854300, 115646254, 28362
# ...

# %%
tweet_list
# Out:
#                        0                                                  1
# 0              107914857  RT @murenasuao: RT @yama_taro_san #安倍総理 は #習近平...
# 1              107914857  RT @murenasuao: RT @taka_3horses 習近平の国賓招待は、中止す...
# 2              107914857  家計調査でわかった「消費増税」の悪影響…日本がいよいよヤバくなる https://t.co/...
# 3              107914857  RT @murenasuao: 中国史を紐解けば、大陸での革命はしばしば南部(広東省)から始...
# 4              107914857  RT @murenasuao: 追い詰められる中国共産党　大統領選挙を前に好景気を維持してお...
# 5              107914857  RT @murenasuao: 堂々と…って。コレ、世界にどんなメッセージを送るコトになるか...
# 6              107914857  RT @watanabeatushi: 中国「すがすがしいネット空間をつくり出す」→ ネット...
# 7              107914857  RT @yas_ka12: 景気回復はフェイクニュース。飲食店の倒産「過去最多」目前で日本は...
# 8              107914857  RT @progkenji: 今年に入ってから外食ほぼ行かなくなったな。業務スーパーの激安食...
# 9              107914857  RT @galapagos77777: 最近、チェーン店も減ってるけど、個人経営の店は特に激...
# 10             107914857       @noboriobrazil 習近平を国賓待遇するのですから、環境整備は期待薄ですね。😢
# ...

# %%
tweet_list001=tweet_list[0:100]
tweet_list002=tweet_list[100:200]
tweet_list003=tweet_list[200:300]
tweet_list004=tweet_list[300:400]
tweet_list005=tweet_list[400:500]
tweet_list006=tweet_list[500:600]
tweet_list007=tweet_list[600:700]
tweet_list008=tweet_list[700:800]
tweet_list009=tweet_list[800:900]
tweet_list010=tweet_list[900:1000]

# %%
df_1=tweet_list[0]
df_2=tweet_list[1]

# %%
df_2=df_2.astype(str)
df_1=df_1.astype(str)

# %%
df_2.to_csv("df2.csv")
# Out:
# /Users/watanabeyuusuke/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
